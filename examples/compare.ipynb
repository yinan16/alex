# %%
from alex.alex import dsl_parser
from alex.alex import compare
import matplotlib as mpl
mpl.rcParams['figure.dpi'] = 600

# %%
config_path_1 = "../examples/configs/small1.yml"
config_path_2 = "../examples/configs/small2.yml"

# %%
render_diff_path = ""
compare.diff(config_path_1, config_path_2, render_to=render_diff_path)
# Out:
# Done computing diff. Rendering image
# Diff images rendered to screen
# (83.0,
#  [('resnet_16_26aa/batch_normalize_15pq',
#    ['INSERT', '', 'batch_normalize#94f00b3e-667d-3c9f-bb9d-54bd33ad52f2#']),
#   ('resnet_16_26aa/batch_normalize_15pq/epsilon/0.001',
#    ['INSERT', '', 'batch_normalize/epsilon/0.001']),
#   ('resnet_16_26aa/batch_normalize_15pq/epsilon',
#    ['INSERT', '', 'batch_normalize/epsilon']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/dtype/float32',
#    ['INSERT', '', 'batch_normalize/mean/dtype/float32']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/dtype',
#    ['INSERT', '', 'batch_normalize/mean/dtype']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/initializer/zeros_initializer',
#    ['INSERT', '', 'batch_normalize/mean/initializer/zeros_initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/initializer',
#    ['INSERT', '', 'batch_normalize/mean/initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/mean/shape/input_shape/channels']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/mean/shape/input_shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/shape',
#    ['INSERT', '', 'batch_normalize/mean/shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean',
#    ['INSERT', '', 'batch_normalize/mean']),
#   ('resnet_16_26aa/batch_normalize_15pq/momentum/0.1',
#    ['INSERT', '', 'batch_normalize/momentum/0.1']),
#   ('resnet_16_26aa/batch_normalize_15pq/momentum',
#    ['INSERT', '', 'batch_normalize/momentum']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/dtype/float32',
#    ['INSERT', '', 'batch_normalize/offset/dtype/float32']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/dtype',
#    ['INSERT', '', 'batch_normalize/offset/dtype']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/initializer/zeros_initializer',
#    ['INSERT', '', 'batch_normalize/offset/initializer/zeros_initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/initializer',
#    ['INSERT', '', 'batch_normalize/offset/initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/offset/shape/input_shape/channels']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/offset/shape/input_shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/shape',
#    ['INSERT', '', 'batch_normalize/offset/shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset',
#    ['INSERT', '', 'batch_normalize/offset']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/dtype/float32',
#    ['INSERT', '', 'batch_normalize/scale/dtype/float32']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/dtype',
#    ['INSERT', '', 'batch_normalize/scale/dtype']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/initializer/ones_initializer',
#    ['INSERT', '', 'batch_normalize/scale/initializer/ones_initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/initializer',
#    ['INSERT', '', 'batch_normalize/scale/initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/scale/shape/input_shape/channels']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/scale/shape/input_shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/shape',
#    ['INSERT', '', 'batch_normalize/scale/shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale',
#    ['INSERT', '', 'batch_normalize/scale']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/dtype/float32',
#    ['INSERT', '', 'batch_normalize/variance/dtype/float32']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/dtype',
#    ['INSERT', '', 'batch_normalize/variance/dtype']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/initializer/ones_initializer',
#    ['INSERT', '', 'batch_normalize/variance/initializer/ones_initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/initializer',
#    ['INSERT', '', 'batch_normalize/variance/initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/variance/shape/input_shape/channels']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/variance/shape/input_shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/shape',
#    ['INSERT', '', 'batch_normalize/variance/shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance',
#    ['INSERT', '', 'batch_normalize/variance']),
#   ('resnet_16_26aa/relu_17rg', ['INSERT', '', 'relu']),
#   ('resnet_16_26aa/conv',
#    ['INSERT', '', 'batch_normalize#94f00b3e-667d-3c9f-bb9d-54bd33ad52f2#']),
#   ('resnet_16_26aa/conv/epsilon/0.001',
#    ['INSERT', '', 'batch_normalize/epsilon/0.001']),
#   ('resnet_16_26aa/conv/epsilon', ['INSERT', '', 'batch_normalize/epsilon']),
#   ('resnet_16_26aa/conv/mean/dtype/float32',
#    ['INSERT', '', 'batch_normalize/mean/dtype/float32']),
#   ('resnet_16_26aa/conv/mean/dtype',
#    ['INSERT', '', 'batch_normalize/mean/dtype']),
#   ('resnet_16_26aa/conv/mean/initializer/zeros_initializer',
#    ['INSERT', '', 'batch_normalize/mean/initializer/zeros_initializer']),
#   ('resnet_16_26aa/conv/mean/initializer',
#    ['INSERT', '', 'batch_normalize/mean/initializer']),
#   ('resnet_16_26aa/conv/mean/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/mean/shape/input_shape/channels']),
#   ('resnet_16_26aa/conv/mean/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/mean/shape/input_shape']),
#   ('resnet_16_26aa/conv/mean/shape',
#    ['INSERT', '', 'batch_normalize/mean/shape']),
#   ('resnet_16_26aa/conv/mean', ['INSERT', '', 'batch_normalize/mean']),
#   ('resnet_16_26aa/conv/momentum/0.1',
#    ['INSERT', '', 'batch_normalize/momentum/0.1']),
#   ('resnet_16_26aa/conv/momentum', ['INSERT', '', 'batch_normalize/momentum']),
#   ('resnet_16_26aa/conv/offset/dtype/float32',
#    ['INSERT', '', 'batch_normalize/offset/dtype/float32']),
#   ('resnet_16_26aa/conv/offset/dtype',
#    ['INSERT', '', 'batch_normalize/offset/dtype']),
#   ('resnet_16_26aa/conv/offset/initializer/zeros_initializer',
#    ['INSERT', '', 'batch_normalize/offset/initializer/zeros_initializer']),
#   ('resnet_16_26aa/conv/offset/initializer',
#    ['INSERT', '', 'batch_normalize/offset/initializer']),
#   ('resnet_16_26aa/conv/offset/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/offset/shape/input_shape/channels']),
#   ('resnet_16_26aa/conv/offset/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/offset/shape/input_shape']),
#   ('resnet_16_26aa/conv/offset/shape',
#    ['INSERT', '', 'batch_normalize/offset/shape']),
#   ('resnet_16_26aa/conv/offset', ['INSERT', '', 'batch_normalize/offset']),
#   ('resnet_16_26aa/conv/scale/dtype/float32',
#    ['INSERT', '', 'batch_normalize/scale/dtype/float32']),
#   ('resnet_16_26aa/conv/scale/dtype',
#    ['INSERT', '', 'batch_normalize/scale/dtype']),
#   ('resnet_16_26aa/conv/scale/initializer/ones_initializer',
#    ['INSERT', '', 'batch_normalize/scale/initializer/ones_initializer']),
#   ('resnet_16_26aa/conv/scale/initializer',
#    ['INSERT', '', 'batch_normalize/scale/initializer']),
#   ('resnet_16_26aa/conv/scale/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/scale/shape/input_shape/channels']),
#   ('resnet_16_26aa/conv/scale/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/scale/shape/input_shape']),
#   ('resnet_16_26aa/conv/scale/shape',
#    ['INSERT', '', 'batch_normalize/scale/shape']),
#   ('resnet_16_26aa/conv/scale', ['INSERT', '', 'batch_normalize/scale']),
#   ('resnet_16_26aa/conv/variance/dtype/float32',
#    ['INSERT', '', 'batch_normalize/variance/dtype/float32']),
#   ('resnet_16_26aa/conv/variance/dtype',
#    ['INSERT', '', 'batch_normalize/variance/dtype']),
#   ('resnet_16_26aa/conv/variance/initializer/ones_initializer',
#    ['INSERT', '', 'batch_normalize/variance/initializer/ones_initializer']),
#   ('resnet_16_26aa/conv/variance/initializer',
#    ['INSERT', '', 'batch_normalize/variance/initializer']),
#   ('resnet_16_26aa/conv/variance/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/variance/shape/input_shape/channels']),
#   ('resnet_16_26aa/conv/variance/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/variance/shape/input_shape']),
#   ('resnet_16_26aa/conv/variance/shape',
#    ['INSERT', '', 'batch_normalize/variance/shape']),
#   ('resnet_16_26aa/conv/variance', ['INSERT', '', 'batch_normalize/variance']),
#   ('resnet_16_26aa/add_23xc', ['INSERT', '', 'add']),
#   ('resnet_16_26aa/relu_25zs', ['INSERT', '', 'relu']),
#   ('resnet_16_26aa', ['INSERT', '', 'resnet_16']),
#   ('d_1', ['INSERT', '', 'sigmoid']),
#   ('regularizer',
#    ['DELETE', 'regularizer_l2#a7bb6351-d794-3b08-80d2-a2155a21c9e5#', '']),
#   ('regularizer/coeff/0.002', ['DELETE', 'regularizer_l2/coeff/0.002', '']),
#   ('regularizer/coeff', ['DELETE', 'regularizer_l2/coeff', '']),
#   ('losses', ['DELETE', 'add', ''])])

# %%
render_dist_path = ""
compare.dist(config_path_1, config_path_2, render_to=render_dist_path)
# Out:
# Done computing distance. Rendering image
# Distance images rendered to screen
# (83.0,
#  [(('input_data/shape/batch_size/None', 'input_data/shape/batch_size/None'),
#    ['MATCH', 'data/shape/batch_size/None', 'data/shape/batch_size/None']),
#   (('input_data/shape/batch_size', 'input_data/shape/batch_size'),
#    ['MATCH', 'data/shape/batch_size', 'data/shape/batch_size']),
#   (('input_data/shape/channels/3', 'input_data/shape/channels/3'),
#    ['MATCH', 'data/shape/channels/3', 'data/shape/channels/3']),
#   (('input_data/shape/channels', 'input_data/shape/channels'),
#    ['MATCH', 'data/shape/channels', 'data/shape/channels']),
#   (('input_data/shape/height/32', 'input_data/shape/height/32'),
#    ['MATCH', 'data/shape/height/32', 'data/shape/height/32']),
#   (('input_data/shape/height', 'input_data/shape/height'),
#    ['MATCH', 'data/shape/height', 'data/shape/height']),
#   (('input_data/shape/width/32', 'input_data/shape/width/32'),
#    ['MATCH', 'data/shape/width/32', 'data/shape/width/32']),
#   (('input_data/shape/width', 'input_data/shape/width'),
#    ['MATCH', 'data/shape/width', 'data/shape/width']),
#   (('input_data/shape', 'input_data/shape'),
#    ['MATCH', 'data/shape', 'data/shape']),
#   (('input_data', 'input_data'), ['MATCH', 'data', 'data']),
#   (('labels/shape/batch_size/None', 'labels/shape/batch_size/None'),
#    ['MATCH', 'label/shape/batch_size/None', 'label/shape/batch_size/None']),
#   (('labels/shape/batch_size', 'labels/shape/batch_size'),
#    ['MATCH', 'label/shape/batch_size', 'label/shape/batch_size']),
#   (('labels/shape/dim/10', 'labels/shape/dim/10'),
#    ['MATCH', 'label/shape/dim/10', 'label/shape/dim/10']),
#   (('labels/shape/dim', 'labels/shape/dim'),
#    ['MATCH', 'label/shape/dim', 'label/shape/dim']),
#   (('labels/shape', 'labels/shape'), ['MATCH', 'label/shape', 'label/shape']),
#   (('labels', 'labels'), ['MATCH', 'label', 'label']),
#   (('conv_5fo/dilation/1', 'conv_5fo/dilation/1'),
#    ['MATCH', 'conv/dilation/1', 'conv/dilation/1']),
#   (('conv_5fo/dilation', 'conv_5fo/dilation'),
#    ['MATCH', 'conv/dilation', 'conv/dilation']),
#   (('conv_5fo/filters/dtype/float32', 'conv_5fo/filters/dtype/float32'),
#    ['MATCH', 'conv/filters/dtype/float32', 'conv/filters/dtype/float32']),
#   (('conv_5fo/filters/dtype', 'conv_5fo/filters/dtype'),
#    ['MATCH', 'conv/filters/dtype', 'conv/filters/dtype']),
#   (('conv_5fo/filters/initializer/xavier_uniform/seed/1',
#     'conv_5fo/filters/initializer/xavier_uniform/seed/1'),
#    ['MATCH',
#     'conv/filters/initializer/xavier_uniform/seed/1',
#     'conv/filters/initializer/xavier_uniform/seed/1']),
#   (('conv_5fo/filters/initializer/xavier_uniform/seed',
#     'conv_5fo/filters/initializer/xavier_uniform/seed'),
#    ['MATCH',
#     'conv/filters/initializer/xavier_uniform/seed',
#     'conv/filters/initializer/xavier_uniform/seed']),
#   (('conv_5fo/filters/initializer/xavier_uniform',
#     'conv_5fo/filters/initializer/xavier_uniform'),
#    ['MATCH',
#     'conv/filters/initializer/xavier_uniform',
#     'conv/filters/initializer/xavier_uniform']),
#   (('conv_5fo/filters/initializer', 'conv_5fo/filters/initializer'),
#    ['MATCH', 'conv/filters/initializer', 'conv/filters/initializer']),
#   (('conv_5fo/filters/shape/input_shape/channels',
#     'conv_5fo/filters/shape/input_shape/channels'),
#    ['MATCH',
#     'conv/filters/shape/input_shape/channels',
#     'conv/filters/shape/input_shape/channels']),
#   (('conv_5fo/filters/shape/input_shape',
#     'conv_5fo/filters/shape/input_shape'),
#    ['MATCH',
#     'conv/filters/shape/input_shape',
#     'conv/filters/shape/input_shape']),
#   (('conv_5fo/filters/shape/kernel_size_h/3',
#     'conv_5fo/filters/shape/kernel_size_h/3'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_h/3',
#     'conv/filters/shape/kernel_size_h/3']),
#   (('conv_5fo/filters/shape/kernel_size_h',
#     'conv_5fo/filters/shape/kernel_size_h'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_h',
#     'conv/filters/shape/kernel_size_h']),
#   (('conv_5fo/filters/shape/kernel_size_w/3',
#     'conv_5fo/filters/shape/kernel_size_w/3'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_w/3',
#     'conv/filters/shape/kernel_size_w/3']),
#   (('conv_5fo/filters/shape/kernel_size_w',
#     'conv_5fo/filters/shape/kernel_size_w'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_w',
#     'conv/filters/shape/kernel_size_w']),
#   (('conv_5fo/filters/shape/n_filters/16',
#     'conv_5fo/filters/shape/n_filters/16'),
#    ['MATCH',
#     'conv/filters/shape/n_filters/16',
#     'conv/filters/shape/n_filters/16']),
#   (('conv_5fo/filters/shape/n_filters', 'conv_5fo/filters/shape/n_filters'),
#    ['MATCH', 'conv/filters/shape/n_filters', 'conv/filters/shape/n_filters']),
#   (('conv_5fo/filters/shape', 'conv_5fo/filters/shape'),
#    ['MATCH', 'conv/filters/shape', 'conv/filters/shape']),
#   (('conv_5fo/filters', 'conv_5fo/filters'),
#    ['MATCH', 'conv/filters', 'conv/filters']),
#   (('conv_5fo/padding/SAME', 'conv_5fo/padding/SAME'),
#    ['MATCH', 'conv/padding/SAME', 'conv/padding/SAME']),
#   (('conv_5fo/padding', 'conv_5fo/padding'),
#    ['MATCH', 'conv/padding', 'conv/padding']),
#   (('conv_5fo/strides/2_0', 'conv_5fo/strides/2_0'),
#    ['MATCH', 'conv/strides/2', 'conv/strides/2']),
#   (('conv_5fo/strides/2_1', 'conv_5fo/strides/2_1'),
#    ['MATCH', 'conv/strides/2/2', 'conv/strides/2/2']),
#   (('conv_5fo/strides', 'conv_5fo/strides'),
#    ['MATCH', 'conv/strides', 'conv/strides']),
#   (('conv_5fo', 'conv_5fo'), ['MATCH', 'conv', 'conv']),
#   (('reluu', 'relu_7he'), ['MATCH', 'relu', 'relu']),
#   (('dropout_9ju/dropout_rate/0.2', 'dropout_9ju/dropout_rate/0.2'),
#    ['MATCH', 'dropout/dropout_rate/0.2', 'dropout/dropout_rate/0.2']),
#   (('dropout_9ju/dropout_rate', 'dropout_9ju/dropout_rate'),
#    ['MATCH', 'dropout/dropout_rate', 'dropout/dropout_rate']),
#   (('dropout_9ju', 'dropout_9ju'), ['MATCH', 'dropout', 'dropout']),
#   (('batch_normalize_11lk/epsilon/0.001',
#     'batch_normalize_11lk/epsilon/0.001'),
#    ['MATCH',
#     'batch_normalize/epsilon/0.001',
#     'batch_normalize/epsilon/0.001']),
#   (('batch_normalize_11lk/epsilon', 'batch_normalize_11lk/epsilon'),
#    ['MATCH', 'batch_normalize/epsilon', 'batch_normalize/epsilon']),
#   (('batch_normalize_11lk/mean/dtype/float32',
#     'batch_normalize_11lk/mean/dtype/float32'),
#    ['MATCH',
#     'batch_normalize/mean/dtype/float32',
#     'batch_normalize/mean/dtype/float32']),
#   (('batch_normalize_11lk/mean/dtype', 'batch_normalize_11lk/mean/dtype'),
#    ['MATCH', 'batch_normalize/mean/dtype', 'batch_normalize/mean/dtype']),
#   (('batch_normalize_11lk/mean/initializer/zeros_initializer',
#     'batch_normalize_11lk/mean/initializer/zeros_initializer'),
#    ['MATCH',
#     'batch_normalize/mean/initializer/zeros_initializer',
#     'batch_normalize/mean/initializer/zeros_initializer']),
#   (('batch_normalize_11lk/mean/initializer',
#     'batch_normalize_11lk/mean/initializer'),
#    ['MATCH',
#     'batch_normalize/mean/initializer',
#     'batch_normalize/mean/initializer']),
#   (('batch_normalize_11lk/mean/shape/input_shape/channels',
#     'batch_normalize_11lk/mean/shape/input_shape/channels'),
#    ['MATCH',
#     'batch_normalize/mean/shape/input_shape/channels',
#     'batch_normalize/mean/shape/input_shape/channels']),
#   (('batch_normalize_11lk/mean/shape/input_shape',
#     'batch_normalize_11lk/mean/shape/input_shape'),
#    ['MATCH',
#     'batch_normalize/mean/shape/input_shape',
#     'batch_normalize/mean/shape/input_shape']),
#   (('batch_normalize_11lk/mean/shape', 'batch_normalize_11lk/mean/shape'),
#    ['MATCH', 'batch_normalize/mean/shape', 'batch_normalize/mean/shape']),
#   (('batch_normalize_11lk/mean', 'batch_normalize_11lk/mean'),
#    ['MATCH', 'batch_normalize/mean', 'batch_normalize/mean']),
#   (('batch_normalize_11lk/momentum/0.1', 'batch_normalize_11lk/momentum/0.1'),
#    ['MATCH', 'batch_normalize/momentum/0.1', 'batch_normalize/momentum/0.1']),
#   (('batch_normalize_11lk/momentum', 'batch_normalize_11lk/momentum'),
#    ['MATCH', 'batch_normalize/momentum', 'batch_normalize/momentum']),
#   (('batch_normalize_11lk/offset/dtype/float32',
#     'batch_normalize_11lk/offset/dtype/float32'),
#    ['MATCH',
#     'batch_normalize/offset/dtype/float32',
#     'batch_normalize/offset/dtype/float32']),
#   (('batch_normalize_11lk/offset/dtype', 'batch_normalize_11lk/offset/dtype'),
#    ['MATCH', 'batch_normalize/offset/dtype', 'batch_normalize/offset/dtype']),
#   (('batch_normalize_11lk/offset/initializer/zeros_initializer',
#     'batch_normalize_11lk/offset/initializer/zeros_initializer'),
#    ['MATCH',
#     'batch_normalize/offset/initializer/zeros_initializer',
#     'batch_normalize/offset/initializer/zeros_initializer']),
#   (('batch_normalize_11lk/offset/initializer',
#     'batch_normalize_11lk/offset/initializer'),
#    ['MATCH',
#     'batch_normalize/offset/initializer',
#     'batch_normalize/offset/initializer']),
#   (('batch_normalize_11lk/offset/shape/input_shape/channels',
#     'batch_normalize_11lk/offset/shape/input_shape/channels'),
#    ['MATCH',
#     'batch_normalize/offset/shape/input_shape/channels',
#     'batch_normalize/offset/shape/input_shape/channels']),
#   (('batch_normalize_11lk/offset/shape/input_shape',
#     'batch_normalize_11lk/offset/shape/input_shape'),
#    ['MATCH',
#     'batch_normalize/offset/shape/input_shape',
#     'batch_normalize/offset/shape/input_shape']),
#   (('batch_normalize_11lk/offset/shape', 'batch_normalize_11lk/offset/shape'),
#    ['MATCH', 'batch_normalize/offset/shape', 'batch_normalize/offset/shape']),
#   (('batch_normalize_11lk/offset', 'batch_normalize_11lk/offset'),
#    ['MATCH', 'batch_normalize/offset', 'batch_normalize/offset']),
#   (('batch_normalize_11lk/scale/dtype/float32',
#     'batch_normalize_11lk/scale/dtype/float32'),
#    ['MATCH',
#     'batch_normalize/scale/dtype/float32',
#     'batch_normalize/scale/dtype/float32']),
#   (('batch_normalize_11lk/scale/dtype', 'batch_normalize_11lk/scale/dtype'),
#    ['MATCH', 'batch_normalize/scale/dtype', 'batch_normalize/scale/dtype']),
#   (('batch_normalize_11lk/scale/initializer/ones_initializer',
#     'batch_normalize_11lk/scale/initializer/ones_initializer'),
#    ['MATCH',
#     'batch_normalize/scale/initializer/ones_initializer',
#     'batch_normalize/scale/initializer/ones_initializer']),
#   (('batch_normalize_11lk/scale/initializer',
#     'batch_normalize_11lk/scale/initializer'),
#    ['MATCH',
#     'batch_normalize/scale/initializer',
#     'batch_normalize/scale/initializer']),
#   (('batch_normalize_11lk/scale/shape/input_shape/channels',
#     'batch_normalize_11lk/scale/shape/input_shape/channels'),
#    ['MATCH',
#     'batch_normalize/scale/shape/input_shape/channels',
#     'batch_normalize/scale/shape/input_shape/channels']),
#   (('batch_normalize_11lk/scale/shape/input_shape',
#     'batch_normalize_11lk/scale/shape/input_shape'),
#    ['MATCH',
#     'batch_normalize/scale/shape/input_shape',
#     'batch_normalize/scale/shape/input_shape']),
#   (('batch_normalize_11lk/scale/shape', 'batch_normalize_11lk/scale/shape'),
#    ['MATCH', 'batch_normalize/scale/shape', 'batch_normalize/scale/shape']),
#   (('batch_normalize_11lk/scale', 'batch_normalize_11lk/scale'),
#    ['MATCH', 'batch_normalize/scale', 'batch_normalize/scale']),
#   (('batch_normalize_11lk/variance/dtype/float32',
#     'batch_normalize_11lk/variance/dtype/float32'),
#    ['MATCH',
#     'batch_normalize/variance/dtype/float32',
#     'batch_normalize/variance/dtype/float32']),
#   (('batch_normalize_11lk/variance/dtype',
#     'batch_normalize_11lk/variance/dtype'),
#    ['MATCH',
#     'batch_normalize/variance/dtype',
#     'batch_normalize/variance/dtype']),
#   (('batch_normalize_11lk/variance/initializer/ones_initializer',
#     'batch_normalize_11lk/variance/initializer/ones_initializer'),
#    ['MATCH',
#     'batch_normalize/variance/initializer/ones_initializer',
#     'batch_normalize/variance/initializer/ones_initializer']),
#   (('batch_normalize_11lk/variance/initializer',
#     'batch_normalize_11lk/variance/initializer'),
#    ['MATCH',
#     'batch_normalize/variance/initializer',
#     'batch_normalize/variance/initializer']),
#   (('batch_normalize_11lk/variance/shape/input_shape/channels',
#     'batch_normalize_11lk/variance/shape/input_shape/channels'),
#    ['MATCH',
#     'batch_normalize/variance/shape/input_shape/channels',
#     'batch_normalize/variance/shape/input_shape/channels']),
#   (('batch_normalize_11lk/variance/shape/input_shape',
#     'batch_normalize_11lk/variance/shape/input_shape'),
#    ['MATCH',
#     'batch_normalize/variance/shape/input_shape',
#     'batch_normalize/variance/shape/input_shape']),
#   (('batch_normalize_11lk/variance/shape',
#     'batch_normalize_11lk/variance/shape'),
#    ['MATCH',
#     'batch_normalize/variance/shape',
#     'batch_normalize/variance/shape']),
#   (('batch_normalize_11lk/variance', 'batch_normalize_11lk/variance'),
#    ['MATCH', 'batch_normalize/variance', 'batch_normalize/variance']),
#   (('batch_normalize_11lk', 'batch_normalize_11lk'),
#    ['MATCH', 'batch_normalize', 'batch_normalize']),
#   (('conv_13na/dilation/1', 'resnet_16_26aa/conv_13na/dilation/1'),
#    ['MATCH', 'conv/dilation/1', 'conv/dilation/1']),
#   (('conv_13na/dilation', 'resnet_16_26aa/conv_13na/dilation'),
#    ['MATCH', 'conv/dilation', 'conv/dilation']),
#   (('conv_13na/filters/dtype/float32',
#     'resnet_16_26aa/conv_13na/filters/dtype/float32'),
#    ['MATCH', 'conv/filters/dtype/float32', 'conv/filters/dtype/float32']),
#   (('conv_13na/filters/dtype', 'resnet_16_26aa/conv_13na/filters/dtype'),
#    ['MATCH', 'conv/filters/dtype', 'conv/filters/dtype']),
#   (('conv_13na/filters/initializer/xavier_uniform/seed/1',
#     'resnet_16_26aa/conv_13na/filters/initializer/xavier_uniform/seed/1'),
#    ['MATCH',
#     'conv/filters/initializer/xavier_uniform/seed/1',
#     'conv/filters/initializer/xavier_uniform/seed/1']),
#   (('conv_13na/filters/initializer/xavier_uniform/seed',
#     'resnet_16_26aa/conv_13na/filters/initializer/xavier_uniform/seed'),
#    ['MATCH',
#     'conv/filters/initializer/xavier_uniform/seed',
#     'conv/filters/initializer/xavier_uniform/seed']),
#   (('conv_13na/filters/initializer/xavier_uniform',
#     'resnet_16_26aa/conv_13na/filters/initializer/xavier_uniform'),
#    ['MATCH',
#     'conv/filters/initializer/xavier_uniform',
#     'conv/filters/initializer/xavier_uniform']),
#   (('conv_13na/filters/initializer',
#     'resnet_16_26aa/conv_13na/filters/initializer'),
#    ['MATCH', 'conv/filters/initializer', 'conv/filters/initializer']),
#   (('conv_13na/filters/shape/input_shape/channels',
#     'resnet_16_26aa/conv_13na/filters/shape/input_shape/channels'),
#    ['MATCH',
#     'conv/filters/shape/input_shape/channels',
#     'conv/filters/shape/input_shape/channels']),
#   (('conv_13na/filters/shape/input_shape',
#     'resnet_16_26aa/conv_13na/filters/shape/input_shape'),
#    ['MATCH',
#     'conv/filters/shape/input_shape',
#     'conv/filters/shape/input_shape']),
#   (('conv_13na/filters/shape/kernel_size_h/3',
#     'resnet_16_26aa/conv_13na/filters/shape/kernel_size_h/3'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_h/3',
#     'conv/filters/shape/kernel_size_h/3']),
#   (('conv_13na/filters/shape/kernel_size_h',
#     'resnet_16_26aa/conv_13na/filters/shape/kernel_size_h'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_h',
#     'conv/filters/shape/kernel_size_h']),
#   (('conv_13na/filters/shape/kernel_size_w/3',
#     'resnet_16_26aa/conv_13na/filters/shape/kernel_size_w/3'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_w/3',
#     'conv/filters/shape/kernel_size_w/3']),
#   (('conv_13na/filters/shape/kernel_size_w',
#     'resnet_16_26aa/conv_13na/filters/shape/kernel_size_w'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_w',
#     'conv/filters/shape/kernel_size_w']),
#   (('conv_13na/filters/shape/n_filters/16',
#     'resnet_16_26aa/conv_13na/filters/shape/n_filters/16'),
#    ['MATCH',
#     'conv/filters/shape/n_filters/16',
#     'conv/filters/shape/n_filters/16']),
#   (('conv_13na/filters/shape/n_filters',
#     'resnet_16_26aa/conv_13na/filters/shape/n_filters'),
#    ['MATCH', 'conv/filters/shape/n_filters', 'conv/filters/shape/n_filters']),
#   (('conv_13na/filters/shape', 'resnet_16_26aa/conv_13na/filters/shape'),
#    ['MATCH', 'conv/filters/shape', 'conv/filters/shape']),
#   (('conv_13na/filters', 'resnet_16_26aa/conv_13na/filters'),
#    ['MATCH', 'conv/filters', 'conv/filters']),
#   (('conv_13na/padding/SAME', 'resnet_16_26aa/conv_13na/padding/SAME'),
#    ['MATCH', 'conv/padding/SAME', 'conv/padding/SAME']),
#   (('conv_13na/padding', 'resnet_16_26aa/conv_13na/padding'),
#    ['MATCH', 'conv/padding', 'conv/padding']),
#   (('conv_13na/strides/1_0', 'resnet_16_26aa/conv_13na/strides/1_0'),
#    ['MATCH', 'conv/strides/1', 'conv/strides/1']),
#   (('conv_13na/strides/1_1', 'resnet_16_26aa/conv_13na/strides/1_1'),
#    ['MATCH', 'conv/strides/1/1', 'conv/strides/1/1']),
#   (('conv_13na/strides', 'resnet_16_26aa/conv_13na/strides'),
#    ['MATCH', 'conv/strides', 'conv/strides']),
#   (('conv_13na', 'resnet_16_26aa/conv_13na'), ['MATCH', 'conv', 'conv']),
#   ('resnet_16_26aa/batch_normalize_15pq/epsilon/0.001',
#    ['INSERT', '', 'batch_normalize/epsilon/0.001']),
#   ('resnet_16_26aa/batch_normalize_15pq/epsilon',
#    ['INSERT', '', 'batch_normalize/epsilon']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/dtype/float32',
#    ['INSERT', '', 'batch_normalize/mean/dtype/float32']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/dtype',
#    ['INSERT', '', 'batch_normalize/mean/dtype']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/initializer/zeros_initializer',
#    ['INSERT', '', 'batch_normalize/mean/initializer/zeros_initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/initializer',
#    ['INSERT', '', 'batch_normalize/mean/initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/mean/shape/input_shape/channels']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/mean/shape/input_shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean/shape',
#    ['INSERT', '', 'batch_normalize/mean/shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/mean',
#    ['INSERT', '', 'batch_normalize/mean']),
#   ('resnet_16_26aa/batch_normalize_15pq/momentum/0.1',
#    ['INSERT', '', 'batch_normalize/momentum/0.1']),
#   ('resnet_16_26aa/batch_normalize_15pq/momentum',
#    ['INSERT', '', 'batch_normalize/momentum']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/dtype/float32',
#    ['INSERT', '', 'batch_normalize/offset/dtype/float32']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/dtype',
#    ['INSERT', '', 'batch_normalize/offset/dtype']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/initializer/zeros_initializer',
#    ['INSERT', '', 'batch_normalize/offset/initializer/zeros_initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/initializer',
#    ['INSERT', '', 'batch_normalize/offset/initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/offset/shape/input_shape/channels']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/offset/shape/input_shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset/shape',
#    ['INSERT', '', 'batch_normalize/offset/shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/offset',
#    ['INSERT', '', 'batch_normalize/offset']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/dtype/float32',
#    ['INSERT', '', 'batch_normalize/scale/dtype/float32']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/dtype',
#    ['INSERT', '', 'batch_normalize/scale/dtype']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/initializer/ones_initializer',
#    ['INSERT', '', 'batch_normalize/scale/initializer/ones_initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/initializer',
#    ['INSERT', '', 'batch_normalize/scale/initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/scale/shape/input_shape/channels']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/scale/shape/input_shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale/shape',
#    ['INSERT', '', 'batch_normalize/scale/shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/scale',
#    ['INSERT', '', 'batch_normalize/scale']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/dtype/float32',
#    ['INSERT', '', 'batch_normalize/variance/dtype/float32']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/dtype',
#    ['INSERT', '', 'batch_normalize/variance/dtype']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/initializer/ones_initializer',
#    ['INSERT', '', 'batch_normalize/variance/initializer/ones_initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/initializer',
#    ['INSERT', '', 'batch_normalize/variance/initializer']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/variance/shape/input_shape/channels']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/variance/shape/input_shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance/shape',
#    ['INSERT', '', 'batch_normalize/variance/shape']),
#   ('resnet_16_26aa/batch_normalize_15pq/variance',
#    ['INSERT', '', 'batch_normalize/variance']),
#   ('resnet_16_26aa/batch_normalize_15pq', ['INSERT', '', 'batch_normalize']),
#   ('resnet_16_26aa/relu_17rg', ['INSERT', '', 'relu']),
#   (('conv_15pq/dilation/1', 'resnet_16_26aa/conv_19tw/dilation/1'),
#    ['MATCH', 'conv/dilation/1', 'conv/dilation/1']),
#   (('conv_15pq/dilation', 'resnet_16_26aa/conv_19tw/dilation'),
#    ['MATCH', 'conv/dilation', 'conv/dilation']),
#   (('conv_15pq/filters/dtype/float32',
#     'resnet_16_26aa/conv_19tw/filters/dtype/float32'),
#    ['MATCH', 'conv/filters/dtype/float32', 'conv/filters/dtype/float32']),
#   (('conv_15pq/filters/dtype', 'resnet_16_26aa/conv_19tw/filters/dtype'),
#    ['MATCH', 'conv/filters/dtype', 'conv/filters/dtype']),
#   (('conv_15pq/filters/initializer/xavier_uniform/seed/1',
#     'resnet_16_26aa/conv_19tw/filters/initializer/xavier_uniform/seed/1'),
#    ['MATCH',
#     'conv/filters/initializer/xavier_uniform/seed/1',
#     'conv/filters/initializer/xavier_uniform/seed/1']),
#   (('conv_15pq/filters/initializer/xavier_uniform/seed',
#     'resnet_16_26aa/conv_19tw/filters/initializer/xavier_uniform/seed'),
#    ['MATCH',
#     'conv/filters/initializer/xavier_uniform/seed',
#     'conv/filters/initializer/xavier_uniform/seed']),
#   (('conv_15pq/filters/initializer/xavier_uniform',
#     'resnet_16_26aa/conv_19tw/filters/initializer/xavier_uniform'),
#    ['MATCH',
#     'conv/filters/initializer/xavier_uniform',
#     'conv/filters/initializer/xavier_uniform']),
#   (('conv_15pq/filters/initializer',
#     'resnet_16_26aa/conv_19tw/filters/initializer'),
#    ['MATCH', 'conv/filters/initializer', 'conv/filters/initializer']),
#   (('conv_15pq/filters/shape/input_shape/channels',
#     'resnet_16_26aa/conv_19tw/filters/shape/input_shape/channels'),
#    ['MATCH',
#     'conv/filters/shape/input_shape/channels',
#     'conv/filters/shape/input_shape/channels']),
#   (('conv_15pq/filters/shape/input_shape',
#     'resnet_16_26aa/conv_19tw/filters/shape/input_shape'),
#    ['MATCH',
#     'conv/filters/shape/input_shape',
#     'conv/filters/shape/input_shape']),
#   (('conv_15pq/filters/shape/kernel_size_h/3',
#     'resnet_16_26aa/conv_19tw/filters/shape/kernel_size_h/3'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_h/3',
#     'conv/filters/shape/kernel_size_h/3']),
#   (('conv_15pq/filters/shape/kernel_size_h',
#     'resnet_16_26aa/conv_19tw/filters/shape/kernel_size_h'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_h',
#     'conv/filters/shape/kernel_size_h']),
#   (('conv_15pq/filters/shape/kernel_size_w/3',
#     'resnet_16_26aa/conv_19tw/filters/shape/kernel_size_w/3'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_w/3',
#     'conv/filters/shape/kernel_size_w/3']),
#   (('conv_15pq/filters/shape/kernel_size_w',
#     'resnet_16_26aa/conv_19tw/filters/shape/kernel_size_w'),
#    ['MATCH',
#     'conv/filters/shape/kernel_size_w',
#     'conv/filters/shape/kernel_size_w']),
#   (('conv_15pq/filters/shape/n_filters/16',
#     'resnet_16_26aa/conv_19tw/filters/shape/n_filters/16'),
#    ['MATCH',
#     'conv/filters/shape/n_filters/16',
#     'conv/filters/shape/n_filters/16']),
#   (('conv_15pq/filters/shape/n_filters',
#     'resnet_16_26aa/conv_19tw/filters/shape/n_filters'),
#    ['MATCH', 'conv/filters/shape/n_filters', 'conv/filters/shape/n_filters']),
#   (('conv_15pq/filters/shape', 'resnet_16_26aa/conv_19tw/filters/shape'),
#    ['MATCH', 'conv/filters/shape', 'conv/filters/shape']),
#   (('conv_15pq/filters', 'resnet_16_26aa/conv_19tw/filters'),
#    ['MATCH', 'conv/filters', 'conv/filters']),
#   (('conv_15pq/padding/SAME', 'resnet_16_26aa/conv_19tw/padding/SAME'),
#    ['MATCH', 'conv/padding/SAME', 'conv/padding/SAME']),
#   (('conv_15pq/padding', 'resnet_16_26aa/conv_19tw/padding'),
#    ['MATCH', 'conv/padding', 'conv/padding']),
#   (('conv_15pq/strides/1_0', 'resnet_16_26aa/conv_19tw/strides/1_0'),
#    ['MATCH', 'conv/strides/1', 'conv/strides/1']),
#   (('conv_15pq/strides/1_1', 'resnet_16_26aa/conv_19tw/strides/1_1'),
#    ['MATCH', 'conv/strides/1/1', 'conv/strides/1/1']),
#   (('conv_15pq/strides', 'resnet_16_26aa/conv_19tw/strides'),
#    ['MATCH', 'conv/strides', 'conv/strides']),
#   (('conv_15pq', 'resnet_16_26aa/conv_19tw'), ['MATCH', 'conv', 'conv']),
#   ('resnet_16_26aa/conv/epsilon/0.001',
#    ['INSERT', '', 'batch_normalize/epsilon/0.001']),
#   ('resnet_16_26aa/conv/epsilon', ['INSERT', '', 'batch_normalize/epsilon']),
#   ('resnet_16_26aa/conv/mean/dtype/float32',
#    ['INSERT', '', 'batch_normalize/mean/dtype/float32']),
#   ('resnet_16_26aa/conv/mean/dtype',
#    ['INSERT', '', 'batch_normalize/mean/dtype']),
#   ('resnet_16_26aa/conv/mean/initializer/zeros_initializer',
#    ['INSERT', '', 'batch_normalize/mean/initializer/zeros_initializer']),
#   ('resnet_16_26aa/conv/mean/initializer',
#    ['INSERT', '', 'batch_normalize/mean/initializer']),
#   ('resnet_16_26aa/conv/mean/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/mean/shape/input_shape/channels']),
#   ('resnet_16_26aa/conv/mean/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/mean/shape/input_shape']),
#   ('resnet_16_26aa/conv/mean/shape',
#    ['INSERT', '', 'batch_normalize/mean/shape']),
#   ('resnet_16_26aa/conv/mean', ['INSERT', '', 'batch_normalize/mean']),
#   ('resnet_16_26aa/conv/momentum/0.1',
#    ['INSERT', '', 'batch_normalize/momentum/0.1']),
#   ('resnet_16_26aa/conv/momentum', ['INSERT', '', 'batch_normalize/momentum']),
#   ('resnet_16_26aa/conv/offset/dtype/float32',
#    ['INSERT', '', 'batch_normalize/offset/dtype/float32']),
#   ('resnet_16_26aa/conv/offset/dtype',
#    ['INSERT', '', 'batch_normalize/offset/dtype']),
#   ('resnet_16_26aa/conv/offset/initializer/zeros_initializer',
#    ['INSERT', '', 'batch_normalize/offset/initializer/zeros_initializer']),
#   ('resnet_16_26aa/conv/offset/initializer',
#    ['INSERT', '', 'batch_normalize/offset/initializer']),
#   ('resnet_16_26aa/conv/offset/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/offset/shape/input_shape/channels']),
#   ('resnet_16_26aa/conv/offset/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/offset/shape/input_shape']),
#   ('resnet_16_26aa/conv/offset/shape',
#    ['INSERT', '', 'batch_normalize/offset/shape']),
#   ('resnet_16_26aa/conv/offset', ['INSERT', '', 'batch_normalize/offset']),
#   ('resnet_16_26aa/conv/scale/dtype/float32',
#    ['INSERT', '', 'batch_normalize/scale/dtype/float32']),
#   ('resnet_16_26aa/conv/scale/dtype',
#    ['INSERT', '', 'batch_normalize/scale/dtype']),
#   ('resnet_16_26aa/conv/scale/initializer/ones_initializer',
#    ['INSERT', '', 'batch_normalize/scale/initializer/ones_initializer']),
#   ('resnet_16_26aa/conv/scale/initializer',
#    ['INSERT', '', 'batch_normalize/scale/initializer']),
#   ('resnet_16_26aa/conv/scale/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/scale/shape/input_shape/channels']),
#   ('resnet_16_26aa/conv/scale/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/scale/shape/input_shape']),
#   ('resnet_16_26aa/conv/scale/shape',
#    ['INSERT', '', 'batch_normalize/scale/shape']),
#   ('resnet_16_26aa/conv/scale', ['INSERT', '', 'batch_normalize/scale']),
#   ('resnet_16_26aa/conv/variance/dtype/float32',
#    ['INSERT', '', 'batch_normalize/variance/dtype/float32']),
#   ('resnet_16_26aa/conv/variance/dtype',
#    ['INSERT', '', 'batch_normalize/variance/dtype']),
#   ('resnet_16_26aa/conv/variance/initializer/ones_initializer',
#    ['INSERT', '', 'batch_normalize/variance/initializer/ones_initializer']),
#   ('resnet_16_26aa/conv/variance/initializer',
#    ['INSERT', '', 'batch_normalize/variance/initializer']),
#   ('resnet_16_26aa/conv/variance/shape/input_shape/channels',
#    ['INSERT', '', 'batch_normalize/variance/shape/input_shape/channels']),
#   ('resnet_16_26aa/conv/variance/shape/input_shape',
#    ['INSERT', '', 'batch_normalize/variance/shape/input_shape']),
#   ('resnet_16_26aa/conv/variance/shape',
#    ['INSERT', '', 'batch_normalize/variance/shape']),
#   ('resnet_16_26aa/conv/variance', ['INSERT', '', 'batch_normalize/variance']),
#   ('resnet_16_26aa/conv', ['INSERT', '', 'batch_normalize']),
#   ('resnet_16_26aa/add_23xc', ['INSERT', '', 'add']),
#   ('resnet_16_26aa/relu_25zs', ['INSERT', '', 'relu']),
#   ('resnet_16_26aa', ['INSERT', '', 'resnet_16']),
#   (('flatten_17rg', 'flatten_28cq'), ['MATCH', 'flatten', 'flatten']),
#   (('dense_19tw/bias/dtype/float32', 'dense_30eg/bias/dtype/float32'),
#    ['MATCH', 'dense/bias/dtype/float32', 'dense/bias/dtype/float32']),
#   (('dense_19tw/bias/dtype', 'dense_30eg/bias/dtype'),
#    ['MATCH', 'dense/bias/dtype', 'dense/bias/dtype']),
#   (('dense_19tw/bias/initializer/zeros_initializer',
#     'dense_30eg/bias/initializer/zeros_initializer'),
#    ['MATCH',
#     'dense/bias/initializer/zeros_initializer',
#     'dense/bias/initializer/zeros_initializer']),
#   (('dense_19tw/bias/initializer', 'dense_30eg/bias/initializer'),
#    ['MATCH', 'dense/bias/initializer', 'dense/bias/initializer']),
#   (('dense_19tw/bias/shape/dim/1', 'dense_30eg/bias/shape/dim/1'),
#    ['MATCH', 'dense/bias/shape/dim/1', 'dense/bias/shape/dim/1']),
#   (('dense_19tw/bias/shape/dim', 'dense_30eg/bias/shape/dim'),
#    ['MATCH', 'dense/bias/shape/dim', 'dense/bias/shape/dim']),
#   (('dense_19tw/bias/shape', 'dense_30eg/bias/shape'),
#    ['MATCH', 'dense/bias/shape', 'dense/bias/shape']),
#   (('dense_19tw/bias', 'dense_30eg/bias'),
#    ['MATCH', 'dense/bias', 'dense/bias']),
#   (('dense_19tw/weights/dtype/float32', 'dense_30eg/weights/dtype/float32'),
#    ['MATCH', 'dense/weights/dtype/float32', 'dense/weights/dtype/float32']),
#   (('dense_19tw/weights/dtype', 'dense_30eg/weights/dtype'),
#    ['MATCH', 'dense/weights/dtype', 'dense/weights/dtype']),
#   (('dense_19tw/weights/initializer/xavier_uniform/seed/2',
#     'dense_30eg/weights/initializer/xavier_uniform/seed/2'),
#    ['MATCH',
#     'dense/weights/initializer/xavier_uniform/seed/2',
#     'dense/weights/initializer/xavier_uniform/seed/2']),
#   (('dense_19tw/weights/initializer/xavier_uniform/seed',
#     'dense_30eg/weights/initializer/xavier_uniform/seed'),
#    ['MATCH',
#     'dense/weights/initializer/xavier_uniform/seed',
#     'dense/weights/initializer/xavier_uniform/seed']),
#   (('dense_19tw/weights/initializer/xavier_uniform',
#     'dense_30eg/weights/initializer/xavier_uniform'),
#    ['MATCH',
#     'dense/weights/initializer/xavier_uniform',
#     'dense/weights/initializer/xavier_uniform']),
#   (('dense_19tw/weights/initializer', 'dense_30eg/weights/initializer'),
#    ['MATCH', 'dense/weights/initializer', 'dense/weights/initializer']),
#   (('dense_19tw/weights/shape/input_shape/channels',
#     'dense_30eg/weights/shape/input_shape/channels'),
#    ['MATCH',
#     'dense/weights/shape/input_shape/channels',
#     'dense/weights/shape/input_shape/channels']),
#   (('dense_19tw/weights/shape/input_shape',
#     'dense_30eg/weights/shape/input_shape'),
#    ['MATCH',
#     'dense/weights/shape/input_shape',
#     'dense/weights/shape/input_shape']),
#   (('dense_19tw/weights/shape/n_units/10',
#     'dense_30eg/weights/shape/n_units/10'),
#    ['MATCH',
#     'dense/weights/shape/n_units/10',
#     'dense/weights/shape/n_units/10']),
#   (('dense_19tw/weights/shape/n_units', 'dense_30eg/weights/shape/n_units'),
#    ['MATCH', 'dense/weights/shape/n_units', 'dense/weights/shape/n_units']),
#   (('dense_19tw/weights/shape', 'dense_30eg/weights/shape'),
#    ['MATCH', 'dense/weights/shape', 'dense/weights/shape']),
#   (('dense_19tw/weights', 'dense_30eg/weights'),
#    ['MATCH', 'dense/weights', 'dense/weights']),
#   (('dense_19tw', 'dense_30eg'), ['MATCH', 'dense', 'dense']),
#   (('d_1', 'softmax_32gw'), ['MATCH', 'softmax', 'softmax']),
#   ('d_1', ['INSERT', '', 'sigmoid']),
#   (('cross_0', 'losses'), ['MATCH', 'cross_entropy', 'cross_entropy']),
#   ('regularizer/coeff/0.002', ['DELETE', 'regularizer_l2/coeff/0.002', '']),
#   ('regularizer/coeff', ['DELETE', 'regularizer_l2/coeff', '']),
#   ('regularizer', ['DELETE', 'regularizer_l2', '']),
#   ('losses', ['DELETE', 'add', '']),
#   (('solver/beta1/0.9', 'solver/beta1/0.9'),
#    ['MATCH', 'adam/beta1/0.9', 'adam/beta1/0.9']),
#   (('solver/beta1', 'solver/beta1'), ['MATCH', 'adam/beta1', 'adam/beta1']),
#   (('solver/beta2/0.999', 'solver/beta2/0.999'),
#    ['MATCH', 'adam/beta2/0.999', 'adam/beta2/0.999']),
#   (('solver/beta2', 'solver/beta2'), ['MATCH', 'adam/beta2', 'adam/beta2']),
#   (('solver/decay/exponential_decay/decay_rate/0.96',
#     'solver/decay/exponential_decay/decay_rate/0.96'),
#    ['MATCH',
#     'adam/decay/exponential_decay/decay_rate/0.96',
#     'adam/decay/exponential_decay/decay_rate/0.96']),
#   (('solver/decay/exponential_decay/decay_rate',
#     'solver/decay/exponential_decay/decay_rate'),
#    ['MATCH',
#     'adam/decay/exponential_decay/decay_rate',
#     'adam/decay/exponential_decay/decay_rate']),
#   (('solver/decay/exponential_decay/decay_steps/100000',
#     'solver/decay/exponential_decay/decay_steps/100000'),
#    ['MATCH',
#     'adam/decay/exponential_decay/decay_steps/100000',
#     'adam/decay/exponential_decay/decay_steps/100000']),
#   (('solver/decay/exponential_decay/decay_steps',
#     'solver/decay/exponential_decay/decay_steps'),
#    ['MATCH',
#     'adam/decay/exponential_decay/decay_steps',
#     'adam/decay/exponential_decay/decay_steps']),
#   (('solver/decay/exponential_decay/initial_learning_rate/0.0001',
#     'solver/decay/exponential_decay/initial_learning_rate/0.0001'),
#    ['MATCH',
#     'adam/decay/exponential_decay/initial_learning_rate/0.0001',
#     'adam/decay/exponential_decay/initial_learning_rate/0.0001']),
#   (('solver/decay/exponential_decay/initial_learning_rate',
#     'solver/decay/exponential_decay/initial_learning_rate'),
#    ['MATCH',
#     'adam/decay/exponential_decay/initial_learning_rate',
#     'adam/decay/exponential_decay/initial_learning_rate']),
#   (('solver/decay/exponential_decay/staircase/True',
#     'solver/decay/exponential_decay/staircase/True'),
#    ['MATCH',
#     'adam/decay/exponential_decay/staircase/True',
#     'adam/decay/exponential_decay/staircase/True']),
#   (('solver/decay/exponential_decay/staircase',
#     'solver/decay/exponential_decay/staircase'),
#    ['MATCH',
#     'adam/decay/exponential_decay/staircase',
#     'adam/decay/exponential_decay/staircase']),
#   (('solver/decay/exponential_decay', 'solver/decay/exponential_decay'),
#    ['MATCH', 'adam/decay/exponential_decay', 'adam/decay/exponential_decay']),
#   (('solver/decay', 'solver/decay'), ['MATCH', 'adam/decay', 'adam/decay']),
#   (('solver/epsilon/1e-08', 'solver/epsilon/1e-08'),
#    ['MATCH', 'adam/epsilon/1e-08', 'adam/epsilon/1e-08']),
#   (('solver/epsilon', 'solver/epsilon'),
#    ['MATCH', 'adam/epsilon', 'adam/epsilon']),
#   (('solver/learning_rate/0.0001', 'solver/learning_rate/0.0001'),
#    ['MATCH', 'adam/learning_rate/0.0001', 'adam/learning_rate/0.0001']),
#   (('solver/learning_rate', 'solver/learning_rate'),
#    ['MATCH', 'adam/learning_rate', 'adam/learning_rate']),
#   (('solver', 'solver'), ['MATCH', 'adam', 'adam']),
#   (('root', 'root'), ['MATCH', 'root', 'root'])])
